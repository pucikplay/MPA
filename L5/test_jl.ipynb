# %%
using Distributions
using Statistics
using Plots
include("boltzmann_train.jl")

g = Geometric(1-0.9)
histogram([rand(g) for _ in 1:100000]; bins = 0:1:100)

# %%
l = LogSer(0.5)
histogram([loga(0.5,5) for _ in 1:10000]; bins = 1:1:10)
